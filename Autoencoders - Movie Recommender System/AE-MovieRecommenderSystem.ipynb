# %% [markdown]
# ## Movie Recommender System Using AutoEncoders In PyTorch
#
# ### Movie rating is between 1 and 5 stars

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data
from torch.autograd import Variable

# %%
# Importing the dataset
movies = pd.read_csv('ml-1m/movies.dat', sep = '::', header = None, engine = 'python', encoding = 'latin-1')
users = pd.read_csv('ml-1m/users.dat', sep = '::', header = None, engine = 'python', encoding = 'latin-1')
ratings = pd.read_csv('ml-1m/ratings.dat', sep = '::', header = None, engine = 'python', encoding = 'latin-1')

# %%
# Preparing the training set and the test set
#training_set = pd.read_csv('ml-100k/u1.base', delimiter = '\t')
training_set = pd.read_csv('ml-1m/training_set.csv', sep = ',')
print(training_set.head())
training_set = np.array(training_set, dtype = 'int')
#test_set = pd.read_csv('ml-100k/u1.test', delimiter = '\t')
test_set = pd.read_csv('ml-1m/test_set.csv', sep = ',')
print('\n',test_set.head())
test_set = np.array(test_set, dtype = 'int')
# Out:
#    User  Movie  Rating  Timestamp
# 0     1    661       3  978302109
# 1     1    914       3  978301968
# 2     1   3408       4  978300275
# 3     1   2355       5  978824291
# 4     1   1287       5  978302039
#
#     User  Movie  Rating  Timestamp
# 0     1   1193       5  978300760
# 1     1   1197       3  978302268
# 2     1   2804       5  978300719
# 3     1    595       5  978824268
# 4     1    938       4  978301752

# %%
# Getting the number of users and movies
nb_users = int(max(max(training_set[:,0]), max(test_set[:,0])))
nb_movies = int(max(max(training_set[:,1]), max(test_set[:,1])))

# %%
# Converting the data into an array with users in lines and movies in columns
def convert(data):
    new_data = []
    for id_users in range(1, nb_users + 1):
        id_movies = data[:,1][data[:,0] == id_users]
        id_ratings = data[:,2][data[:,0] == id_users]
        ratings = np.zeros(nb_movies)
        ratings[id_movies - 1] = id_ratings
        new_data.append(list(ratings))
    return new_data
training_set = convert(training_set)
test_set = convert(test_set)

# %%
# Converting the data into Torch tensors
training_set = torch.FloatTensor(training_set)
test_set = torch.FloatTensor(test_set)

# %%
# Creating the architecture of the Neural Network
class SAE(nn.Module):
    def __init__(self, ):
        super(SAE, self).__init__()
        self.fc1 = nn.Linear(nb_movies, 20)
        self.fc2 = nn.Linear(20, 10)
        self.fc3 = nn.Linear(10, 20)
        self.fc4 = nn.Linear(20, nb_movies)
        self.activation = nn.Sigmoid()
    def forward(self, x):
        x = self.activation(self.fc1(x))
        x = self.activation(self.fc2(x))
        x = self.activation(self.fc3(x))
        x = self.fc4(x)
        return x
sae = SAE()
criterion = nn.MSELoss()
optimizer = optim.RMSprop(sae.parameters(), lr = 0.01, weight_decay = 0.5)

# %%
# Training the SAE
nb_epoch = 200
for epoch in range(1, nb_epoch + 1):
    train_loss = 0
    s = 0.
    for id_user in range(nb_users):
        input = Variable(training_set[id_user]).unsqueeze(0)
        target = input.clone()
        if torch.sum(target.data > 0) > 0:
            output = sae(input)
            target.require_grad = False
            output[target == 0] = 0
            loss = criterion(output, target)
            mean_corrector = nb_movies/float(torch.sum(target.data > 0) + 1e-10)
            loss.backward()
            train_loss += np.sqrt(loss.data[0]*mean_corrector)
            s += 1.
            optimizer.step()
    print('epoch: '+str(epoch)+' loss: '+str(train_loss/s))
# Out:
# C:\Users\AK\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:16: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   app.launch_new_instance()
# epoch: 1 loss: tensor(1.3478)
# epoch: 2 loss: tensor(1.0102)
# epoch: 3 loss: tensor(0.9900)
# epoch: 4 loss: tensor(0.9833)
# epoch: 5 loss: tensor(0.9801)
# epoch: 6 loss: tensor(0.9786)
# epoch: 7 loss: tensor(0.9773)
# epoch: 8 loss: tensor(0.9765)
# epoch: 9 loss: tensor(0.9760)
# epoch: 10 loss: tensor(0.9757)
# epoch: 11 loss: tensor(0.9752)
# epoch: 12 loss: tensor(0.9751)
# epoch: 13 loss: tensor(0.9747)
# epoch: 14 loss: tensor(0.9746)
# epoch: 15 loss: tensor(0.9744)
# epoch: 16 loss: tensor(0.9743)
# epoch: 17 loss: tensor(0.9743)
# epoch: 18 loss: tensor(0.9741)
# epoch: 19 loss: tensor(0.9740)
# epoch: 20 loss: tensor(0.9739)
# epoch: 21 loss: tensor(0.9738)
# epoch: 22 loss: tensor(0.9737)
# epoch: 23 loss: tensor(0.9736)
# epoch: 24 loss: tensor(0.9733)
# epoch: 25 loss: tensor(0.9728)
# epoch: 26 loss: tensor(0.9722)
# epoch: 27 loss: tensor(0.9715)
# epoch: 28 loss: tensor(0.9707)
# epoch: 29 loss: tensor(0.9702)
# epoch: 30 loss: tensor(0.9693)
# epoch: 31 loss: tensor(0.9683)
# epoch: 32 loss: tensor(0.9673)
# epoch: 33 loss: tensor(0.9665)
# epoch: 34 loss: tensor(0.9661)
# epoch: 35 loss: tensor(0.9653)
# epoch: 36 loss: tensor(0.9661)
# epoch: 37 loss: tensor(0.9651)
# epoch: 38 loss: tensor(0.9632)
# epoch: 39 loss: tensor(0.9616)
# epoch: 40 loss: tensor(0.9617)
# epoch: 41 loss: tensor(0.9594)
# epoch: 42 loss: tensor(0.9584)
# epoch: 43 loss: tensor(0.9590)
# epoch: 44 loss: tensor(0.9583)
# epoch: 45 loss: tensor(0.9563)
# epoch: 46 loss: tensor(0.9549)
# epoch: 47 loss: tensor(0.9524)
# epoch: 48 loss: tensor(0.9502)
# epoch: 49 loss: tensor(0.9482)
# epoch: 50 loss: tensor(0.9492)
# epoch: 51 loss: tensor(0.9500)
# epoch: 52 loss: tensor(0.9472)
# epoch: 53 loss: tensor(0.9455)
# epoch: 54 loss: tensor(0.9469)
# epoch: 55 loss: tensor(0.9437)
# epoch: 56 loss: tensor(0.9425)
# epoch: 57 loss: tensor(0.9399)
# epoch: 58 loss: tensor(0.9384)
# epoch: 59 loss: tensor(0.9415)
# epoch: 60 loss: tensor(0.9390)
# epoch: 61 loss: tensor(0.9352)
# epoch: 62 loss: tensor(0.9376)
# epoch: 63 loss: tensor(0.9376)
# epoch: 64 loss: tensor(0.9341)
# epoch: 65 loss: tensor(0.9306)
# epoch: 66 loss: tensor(0.9290)
# epoch: 67 loss: tensor(0.9290)
# epoch: 68 loss: tensor(0.9335)
# epoch: 69 loss: tensor(0.9304)
# epoch: 70 loss: tensor(0.9256)
# epoch: 71 loss: tensor(0.9227)
# epoch: 72 loss: tensor(0.9252)
# epoch: 73 loss: tensor(0.9225)
# epoch: 74 loss: tensor(0.9191)
# epoch: 75 loss: tensor(0.9197)
# epoch: 76 loss: tensor(0.9217)
# epoch: 77 loss: tensor(0.9187)
# epoch: 78 loss: tensor(0.9164)
# epoch: 79 loss: tensor(0.9139)
# epoch: 80 loss: tensor(0.9167)
# epoch: 81 loss: tensor(0.9184)
# epoch: 82 loss: tensor(0.9160)
# epoch: 83 loss: tensor(0.9147)
# epoch: 84 loss: tensor(0.9125)
# epoch: 85 loss: tensor(0.9124)
# epoch: 86 loss: tensor(0.9150)
# epoch: 87 loss: tensor(0.9104)
# epoch: 88 loss: tensor(0.9108)
# epoch: 89 loss: tensor(0.9104)
# epoch: 90 loss: tensor(0.9079)
# epoch: 91 loss: tensor(0.9100)
# epoch: 92 loss: tensor(0.9096)
# epoch: 93 loss: tensor(0.9071)
# epoch: 94 loss: tensor(0.9069)
# epoch: 95 loss: tensor(0.9092)
# epoch: 96 loss: tensor(0.9071)
# epoch: 97 loss: tensor(0.9052)
# epoch: 98 loss: tensor(0.9040)
# epoch: 99 loss: tensor(0.9034)
# epoch: 100 loss: tensor(0.9047)
# epoch: 101 loss: tensor(0.9067)
# epoch: 102 loss: tensor(0.9045)
# epoch: 103 loss: tensor(0.9028)
# epoch: 104 loss: tensor(0.9054)
# epoch: 105 loss: tensor(0.9049)
# epoch: 106 loss: tensor(0.9030)
# epoch: 107 loss: tensor(0.9024)
# epoch: 108 loss: tensor(0.9027)
# epoch: 109 loss: tensor(0.9026)
# epoch: 110 loss: tensor(0.9019)
# epoch: 111 loss: tensor(0.9005)
# epoch: 112 loss: tensor(0.9002)
# epoch: 113 loss: tensor(0.9019)
# epoch: 114 loss: tensor(0.9014)
# epoch: 115 loss: tensor(0.8999)
# epoch: 116 loss: tensor(0.8990)
# epoch: 117 loss: tensor(0.8994)
# epoch: 118 loss: tensor(0.8984)
# epoch: 119 loss: tensor(0.8979)
# epoch: 120 loss: tensor(0.8975)
# epoch: 121 loss: tensor(0.8980)
# epoch: 122 loss: tensor(0.8982)
# epoch: 123 loss: tensor(0.8979)
# epoch: 124 loss: tensor(0.8969)
# epoch: 125 loss: tensor(0.8971)
# epoch: 126 loss: tensor(0.8973)
# epoch: 127 loss: tensor(0.8959)
# epoch: 128 loss: tensor(0.8959)
# epoch: 129 loss: tensor(0.8961)
# epoch: 130 loss: tensor(0.8950)
# epoch: 131 loss: tensor(0.8952)
# epoch: 132 loss: tensor(0.8965)
# epoch: 133 loss: tensor(0.8966)
# epoch: 134 loss: tensor(0.8942)
# epoch: 135 loss: tensor(0.8950)
# epoch: 136 loss: tensor(0.8958)
# epoch: 137 loss: tensor(0.8934)
# epoch: 138 loss: tensor(0.8933)
# epoch: 139 loss: tensor(0.8943)
# epoch: 140 loss: tensor(0.8928)
# epoch: 141 loss: tensor(0.8910)
# epoch: 142 loss: tensor(0.8922)
# epoch: 143 loss: tensor(0.8915)
# epoch: 144 loss: tensor(0.8895)
# epoch: 145 loss: tensor(0.8880)
# epoch: 146 loss: tensor(0.8884)
# epoch: 147 loss: tensor(0.8881)
# epoch: 148 loss: tensor(0.8857)
# epoch: 149 loss: tensor(0.8848)
# epoch: 150 loss: tensor(0.8869)
# epoch: 151 loss: tensor(0.8853)
# epoch: 152 loss: tensor(0.8828)
# epoch: 153 loss: tensor(0.8821)
# epoch: 154 loss: tensor(0.8824)
# epoch: 155 loss: tensor(0.8808)
# epoch: 156 loss: tensor(0.8792)
# epoch: 157 loss: tensor(0.8793)
# epoch: 158 loss: tensor(0.8788)
# epoch: 159 loss: tensor(0.8782)
# epoch: 160 loss: tensor(0.8769)
# epoch: 161 loss: tensor(0.8761)
# epoch: 162 loss: tensor(0.8761)
# epoch: 163 loss: tensor(0.8765)
# epoch: 164 loss: tensor(0.8772)
# epoch: 165 loss: tensor(0.8761)
# epoch: 166 loss: tensor(0.8748)
# epoch: 167 loss: tensor(0.8752)
# epoch: 168 loss: tensor(0.8771)
# epoch: 169 loss: tensor(0.8757)
# epoch: 170 loss: tensor(0.8733)
# epoch: 171 loss: tensor(0.8724)
# epoch: 172 loss: tensor(0.8730)
# epoch: 173 loss: tensor(0.8731)
# epoch: 174 loss: tensor(0.8722)
# epoch: 175 loss: tensor(0.8709)
# epoch: 176 loss: tensor(0.8723)
# epoch: 177 loss: tensor(0.8722)
# epoch: 178 loss: tensor(0.8701)
# epoch: 179 loss: tensor(0.8691)
# epoch: 180 loss: tensor(0.8688)
# epoch: 181 loss: tensor(0.8690)
# epoch: 182 loss: tensor(0.8682)
# epoch: 183 loss: tensor(0.8683)
# epoch: 184 loss: tensor(0.8698)
# epoch: 185 loss: tensor(0.8682)
# epoch: 186 loss: tensor(0.8671)
# epoch: 187 loss: tensor(0.8684)
# epoch: 188 loss: tensor(0.8699)
# epoch: 189 loss: tensor(0.8682)
# epoch: 190 loss: tensor(0.8663)
# epoch: 191 loss: tensor(0.8658)
# epoch: 192 loss: tensor(0.8658)
# epoch: 193 loss: tensor(0.8654)
# epoch: 194 loss: tensor(0.8650)
# epoch: 195 loss: tensor(0.8657)
# epoch: 196 loss: tensor(0.8657)
# epoch: 197 loss: tensor(0.8651)
# epoch: 198 loss: tensor(0.8650)
# epoch: 199 loss: tensor(0.8661)
# epoch: 200 loss: tensor(0.8646)

# %%
# Testing the SAE
test_loss = 0
s = 0.
for id_user in range(nb_users):
    input = Variable(training_set[id_user]).unsqueeze(0)
    target = Variable(test_set[id_user]).unsqueeze(0)
    if torch.sum(target.data > 0) > 0:
        output = sae(input)
        target.require_grad = False
        output[target == 0] = 0
        loss = criterion(output, target)
        mean_corrector = nb_movies/float(torch.sum(target.data > 0) + 1e-10)
        test_loss += np.sqrt(loss.data[0]*mean_corrector)
        s += 1.
print('test loss: '+str(test_loss/s))
# Out:
# C:\Users\AK\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:13: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   del sys.path[0]
# test loss: tensor(0.8965)

# %% [markdown]
# ### The final test set loss is less that one star
